# %% [markdown]
# # Actividad 5: Predicción de Carga Energética con MLflow
#
# **Proyecto:** Predicción de carga energética de edificios mediante Machine Learning
# **Tipo de problema:** Regresión
# **Dataset:** Energy Efficiency Dataset
# **Modelos:** Regresión Lineal y XGBoost Regressor
# **Herramientas:** Python, Scikit-learn, XGBoost, MLflow, VS Code y GitHub
#
# **Alumno:** Jesús Manuel Núñez López
# **Fecha:** Junio 2026

# %% [markdown]
# ## Objetivo
#
# Desarrollar un proyecto aplicado de Machine Learning para predecir la carga de calefacción de edificios utilizando un dataset público. El proyecto incluye preparación de datos, limpieza, visualización, entrenamiento de modelos, ajuste de hiperparámetros, validación cruzada y registro de experimentos con MLflow.
#
# La variable objetivo será **Heating Load**, mientras que los modelos comparados serán:
#
# 1. Regresión Lineal.
# 2. XGBoost Regressor con GridSearchCV.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from ucimlrepo import fetch_ucirepo

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from xgboost import XGBRegressor

import mlflow
import mlflow.sklearn

print("Librerías importadas correctamente.")
